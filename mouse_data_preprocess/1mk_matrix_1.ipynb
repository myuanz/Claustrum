# %%
library(dplyr)
library(Seurat)
library(patchwork)
library(stringr)
library(Matrix)
library(R.utils)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Attaching SeuratObject
#
# Attaching sp
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.25.0 (2022-06-12 02:20:02 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: 'R.oo'
#
#
# The following object is masked from 'package:R.methodsS3':
#
#     throw
#
#
# The following objects are masked from 'package:methods':
#
#     getClasses, getMethods
#
#
# The following objects are masked from 'package:base':
#
#     attach, detach, load, save
#
#
# R.utils v2.12.2 (2022-11-11 22:00:03 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: 'R.utils'
#
#
# The following object is masked from 'package:utils':
#
#     timestamp
#
#
# The following objects are masked from 'package:base':
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, warnings

# %%
all_dir=list.dirs('/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix')
all_dir=all_dir[grep('0$',all_dir)]
length(all_dir)
all_dir
# Out:
# [1] 26
#  [1] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-1-230323_web_0"
#  [2] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-10-230323_web_0"
#  [3] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-2-230323_web_0"
#  [4] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-3-230323_web_0"
#  [5] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-4-230323_web_0"
#  [6] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-5-230323_web_0"
#  [7] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-6-230323_web_0"
#  [8] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-7-230323_web_0"
#  [9] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-8-230323_web_0"
# [10] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-9-230323_web_0"
# [11] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-1-230417_web_0"
# [12] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-10-230417_web_0"
# [13] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-11-230417_web_0"
# [14] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-12-230417_web_0"
# [15] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-13-230417_web_0"
# [16] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-14-230417_web_0"
# [17] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-15-230417_web_0"
# [18] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-16-230417_web_0"
# [19] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-2-230417_web_0"
# [20] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-3-230417_web_0"
# [21] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-4-230417_web_0"
# [22] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-5-230417_web_0"
# [23] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-6-230417_web_0"
# [24] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-7-230417_web_0"
# [25] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-8-230417_web_0"
# [26] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-9-230417_web_0"

# %%
grep('2350-7',all_dir)
# Out:
# [1] 24

# %%
for(i in c(24:length(all_dir))){matrix_dir=all_dir[i]

if(file.exists(paste0(matrix_dir,"/barcodes.tsv.gz"))){
    gunzip(paste0(matrix_dir,"/barcodes.tsv.gz"))
    gunzip(paste0(matrix_dir,"/matrix.mtx.gz"))
    gunzip(paste0(matrix_dir,"/genes.tsv.gz"))

    barcode.path<-paste0(matrix_dir,"/barcodes.tsv")
    genes.path<-paste0(matrix_dir,"/genes.tsv")
    matrix.path<-paste0(matrix_dir,"/matrix.mtx")

    zebrafish.data <- readMM(file = matrix.path) ##mac上不能读压缩文件
    gene.names = read.delim(genes.path,header = FALSE, stringsAsFactors = FALSE)
    barcode.names = read.delim(barcode.path,header = FALSE,stringsAsFactors = FALSE)
    colnames(zebrafish.data) = barcode.names$V1
    rownames(zebrafish.data) = gene.names$V1 ##把示例中的V1改成V2

    # check矩阵
    zebrafish.data[1:6, 1:6] ##check矩阵
    dim(zebrafish.data) ##check矩阵

    scRNA <- CreateSeuratObject(counts = zebrafish.data)

    saveRDS(scRNA,paste0(matrix_dir,'/counts.rds'))
}else{
    matrix_dir=paste0(matrix_dir,'/04.Matrix')
    gunzip(paste0(matrix_dir,"/barcodes.tsv.gz"))
    gunzip(paste0(matrix_dir,"/matrix.mtx.gz"))
    gunzip(paste0(matrix_dir,"/genes.tsv.gz"))

    barcode.path<-paste0(matrix_dir,"/barcodes.tsv")
    genes.path<-paste0(matrix_dir,"/genes.tsv")
    matrix.path<-paste0(matrix_dir,"/matrix.mtx")

    zebrafish.data <- readMM(file = matrix.path) ##mac上不能读压缩文件
    gene.names = read.delim(genes.path,header = FALSE, stringsAsFactors = FALSE)
    barcode.names = read.delim(barcode.path,header = FALSE,stringsAsFactors = FALSE)
    colnames(zebrafish.data) = barcode.names$V1
    rownames(zebrafish.data) = gene.names$V1 ##把示例中的V1改成V2

    # check矩阵
    zebrafish.data[1:6, 1:6] ##check矩阵
    dim(zebrafish.data) ##check矩阵

    scRNA <- CreateSeuratObject(counts = zebrafish.data)

    saveRDS(scRNA,paste0(matrix_dir,'/counts.rds'))
}}

# %%
read_file='aba'
for(i in c(1:length(all_dir))){
matrix_dir=all_dir[i]
if(file.exists(paste0(matrix_dir,"/counts.rds"))){
    read_file=c(read_file,(paste0(matrix_dir,"/counts.rds")))
}else{
    matrix_dir=paste0(matrix_dir,'/04.Matrix')
    read_file=c(read_file,(paste0(matrix_dir,"/counts.rds")))
}}
read_file=read_file[-1]
read_file
# Out:
#  [1] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-1-230323_web_0/04.Matrix/counts.rds"
#  [2] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-10-230323_web_0/04.Matrix/counts.rds"
#  [3] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-2-230323_web_0/04.Matrix/counts.rds"
#  [4] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-3-230323_web_0/04.Matrix/counts.rds"
#  [5] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-4-230323_web_0/04.Matrix/counts.rds"
#  [6] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-5-230323_web_0/04.Matrix/counts.rds"
#  [7] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-6-230323_web_0/04.Matrix/counts.rds"
#  [8] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-7-230323_web_0/04.Matrix/counts.rds"
#  [9] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-8-230323_web_0/04.Matrix/counts.rds"
# [10] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2191-9-230323_web_0/04.Matrix/counts.rds"
# [11] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-1-230417_web_0/04.Matrix/counts.rds"
# [12] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-10-230417_web_0/04.Matrix/counts.rds"
# [13] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-11-230417_web_0/04.Matrix/counts.rds"
# [14] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-12-230417_web_0/04.Matrix/counts.rds"
# [15] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-13-230417_web_0/04.Matrix/counts.rds"
# [16] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-14-230417_web_0/04.Matrix/counts.rds"
# [17] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-15-230417_web_0/04.Matrix/counts.rds"
# [18] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-16-230417_web_0/04.Matrix/counts.rds"
# [19] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-2-230417_web_0/04.Matrix/counts.rds"
# [20] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-3-230417_web_0/04.Matrix/counts.rds"
# [21] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-4-230417_web_0/04.Matrix/counts.rds"
# [22] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-5-230417_web_0/04.Matrix/counts.rds"
# [23] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-6-230417_web_0/04.Matrix/counts.rds"
# [24] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-7-230417_web_0/04.Matrix/counts.rds"
# [25] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-8-230417_web_0/04.Matrix/counts.rds"
# [26] "/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/soupX.flt_Matrix/2350-9-230417_web_0/04.Matrix/counts.rds"

# %%
sceList = lapply(read_file,function(folder){ 
    readRDS(folder)
})
sceList
# Out:
# [[1]]
# An object of class Seurat
# 34697 features across 7766 samples within 1 assay
# Active assay: RNA (34697 features, 0 variable features)
#
# [[2]]
# An object of class Seurat
# 35026 features across 7624 samples within 1 assay
# Active assay: RNA (35026 features, 0 variable features)
#
# [[3]]
# An object of class Seurat
# 34456 features across 7744 samples within 1 assay
# Active assay: RNA (34456 features, 0 variable features)
#
# [[4]]
# An object of class Seurat
# 34995 features across 7652 samples within 1 assay
# Active assay: RNA (34995 features, 0 variable features)
#
# [[5]]
# An object of class Seurat
# 35264 features across 7694 samples within 1 assay
# Active assay: RNA (35264 features, 0 variable features)
#
# [[6]]
# An object of class Seurat
# 34255 features across 7899 samples within 1 assay
# Active assay: RNA (34255 features, 0 variable features)
#
# [[7]]
# An object of class Seurat
# 34438 features across 7477 samples within 1 assay
# Active assay: RNA (34438 features, 0 variable features)
#
# [[8]]
# An object of class Seurat
# 34750 features across 7484 samples within 1 assay
# Active assay: RNA (34750 features, 0 variable features)
#
# [[9]]
# An object of class Seurat
# 34841 features across 7464 samples within 1 assay
# Active assay: RNA (34841 features, 0 variable features)
#
# [[10]]
# An object of class Seurat
# 33859 features across 7717 samples within 1 assay
# Active assay: RNA (33859 features, 0 variable features)
#
# [[11]]
# An object of class Seurat
# 35170 features across 7254 samples within 1 assay
# Active assay: RNA (35170 features, 0 variable features)
#
# [[12]]
# An object of class Seurat
# 37239 features across 7465 samples within 1 assay
# Active assay: RNA (37239 features, 0 variable features)
#
# [[13]]
# An object of class Seurat
# 35209 features across 7314 samples within 1 assay
# Active assay: RNA (35209 features, 0 variable features)
#
# [[14]]
# An object of class Seurat
# 35940 features across 7491 samples within 1 assay
# Active assay: RNA (35940 features, 0 variable features)
#
# [[15]]
# An object of class Seurat
# 36122 features across 7521 samples within 1 assay
# Active assay: RNA (36122 features, 0 variable features)
#
# [[16]]
# An object of class Seurat
# 36736 features across 7531 samples within 1 assay
# Active assay: RNA (36736 features, 0 variable features)
#
# [[17]]
# An object of class Seurat
# 36929 features across 7418 samples within 1 assay
# Active assay: RNA (36929 features, 0 variable features)
#
# [[18]]
# An object of class Seurat
# 36406 features across 7524 samples within 1 assay
# Active assay: RNA (36406 features, 0 variable features)
#
# [[19]]
# An object of class Seurat
# 35885 features across 7399 samples within 1 assay
# Active assay: RNA (35885 features, 0 variable features)
#
# [[20]]
# An object of class Seurat
# 35051 features across 7304 samples within 1 assay
# Active assay: RNA (35051 features, 0 variable features)
#
# [[21]]
# An object of class Seurat
# 36426 features across 7267 samples within 1 assay
# Active assay: RNA (36426 features, 0 variable features)
#
# [[22]]
# An object of class Seurat
# 36986 features across 7424 samples within 1 assay
# Active assay: RNA (36986 features, 0 variable features)
#
# [[23]]
# An object of class Seurat
# 37363 features across 7476 samples within 1 assay
# Active assay: RNA (37363 features, 0 variable features)
#
# [[24]]
# An object of class Seurat
# 36848 features across 7400 samples within 1 assay
# Active assay: RNA (36848 features, 0 variable features)
#
# [[25]]
# An object of class Seurat
# 37531 features across 7566 samples within 1 assay
# Active assay: RNA (37531 features, 0 variable features)
#
# [[26]]
# An object of class Seurat
# 37173 features across 7492 samples within 1 assay
# Active assay: RNA (37173 features, 0 variable features)

# %%
str_extract(read_file,'[0-9][0-9][0-9][0-9]-[0-9]*')
# Out:
#  [1] "2191-1"  "2191-10" "2191-2"  "2191-3"  "2191-4"  "2191-5"  "2191-6"
#  [8] "2191-7"  "2191-8"  "2191-9"  "2350-1"  "2350-10" "2350-11" "2350-12"
# [15] "2350-13" "2350-14" "2350-15" "2350-16" "2350-2"  "2350-3"  "2350-4"
# [22] "2350-5"  "2350-6"  "2350-7"  "2350-8"  "2350-9"

# %%
read_file_renew=str_extract(read_file,'[0-9][0-9][0-9][0-9]-[0-9]*')

read_file_renew

sce.big <- merge(sceList[[1]], 
                 y = c(sceList[[2]],sceList[[3]],sceList[[4]],
                       sceList[[5]],sceList[[6]],
                       sceList[[7]],sceList[[8]],sceList[[9]],sceList[[10]],sceList[[11]],
                       sceList[[12]],sceList[[13]],
                       sceList[[14]], sceList[[15]],sceList[[16]],
                       sceList[[17]],sceList[[18]],sceList[[19]],sceList[[20]],sceList[[21]],
                       sceList[[22]],sceList[[23]],
                       sceList[[24]], sceList[[25]],sceList[[26]]), 
                 add.cell.ids = read_file_renew,
                 project = "mouse")

table(sce.big$orig.ident)

sce.big@meta.data$group=str_extract(rownames(sce.big@meta.data),'[0-9][0-9][0-9][0-9]-[0-9]*')
# Out:
#  [1] "2191-1"  "2191-10" "2191-2"  "2191-3"  "2191-4"  "2191-5"  "2191-6"
#  [8] "2191-7"  "2191-8"  "2191-9"  "2350-1"  "2350-10" "2350-11" "2350-12"
# [15] "2350-13" "2350-14" "2350-15" "2350-16" "2350-2"  "2350-3"  "2350-4"
# [22] "2350-5"  "2350-6"  "2350-7"  "2350-8"  "2350-9"
# SeuratProject
#        195367

# %%
saveRDS(sce.big,'/home/liuyx/liuyuxuan/spa_seurat/cla/mouse/snrna_data/0523_mouse_data/mouse_snrna_all_soupX_unfil_0524.rds')
