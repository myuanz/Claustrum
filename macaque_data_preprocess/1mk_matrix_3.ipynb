# %%
library(dplyr)
library(Seurat)
library(patchwork)
library(stringr)
library(Matrix)
library(R.utils)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# The legacy packages maptools, rgdal, and rgeos, underpinning this package
# will retire shortly. Please refer to R-spatial evolution reports on
# https://r-spatial.org/r/2023/05/15/evolution4.html for details.
# This package is now running under evolution status 0
#
# rgeos version: 0.6-3, (SVN revision 696)
#  GEOS runtime version: 3.11.0-CAPI-1.17.0
#  Please note that rgeos will be retired during October 2023,
# plan transition to sf or terra functions using GEOS at your earliest convenience.
# See https://r-spatial.org/r/2023/05/15/evolution4.html for details.
#  GEOS using OverlayNG
#  Linking to sp version: 1.6-0
#  Polygon checking: TRUE
#
#
# Attaching SeuratObject
#
# Attaching sp

# %%
all_dir=list.dirs('/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix')
all_dir=all_dir[grep('0$',all_dir)]
length(all_dir)
all_dir
# Out:
# [1] 30
#  [1] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6103-1-220817_web_0"
#  [2] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6103-2-220817_web_0"
#  [3] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6103-3-220817_web_0"
#  [4] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6103-4-220817_web_0"
#  [5] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6103-5-220817_web_0"
#  [6] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6103-6-220817_web_0"
#  [7] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6712-1-220831_web_0"
#  [8] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6712-2-220831_web_0"
#  [9] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6712-3-220831_web_0"
# [10] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6712-4-220831_web_0"
# [11] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7220-1-221013_web_0"
# [12] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7220-2-221013_web_0"
# [13] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7221-1-221013_web_0"
# [14] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7221-2-221013_web_0"
# [15] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7222-1-221014_web_0"
# [16] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7222-2-221014_web_0"
# [17] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7223-1-221014_web_0"
# [18] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7223-2-221014_web_0"
# [19] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7224-1-221014_web_0"
# [20] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7224-2-221014_web_0"
# [21] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7230-1-221014_web_0"
# [22] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7230-2-221014_web_0"
# [23] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7231-1-221014_web_0"
# [24] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7231-2-221014_web_0"
# [25] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7231-3-221014_web_0"
# [26] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7232-1-221014_web_0"
# [27] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7232-2-221014_web_0"
# [28] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7232-3-221014_web_0"
# [29] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7248-1-221017_web_0"
# [30] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7248-2-221017_web_0"

# %%
for(i in c(1:length(all_dir))){matrix_dir=all_dir[i]

if(file.exists(paste0(matrix_dir,"/barcodes.tsv.gz"))){
    gunzip(paste0(matrix_dir,"/barcodes.tsv.gz"))
    gunzip(paste0(matrix_dir,"/matrix.mtx.gz"))
    gunzip(paste0(matrix_dir,"/genes.tsv.gz"))

    barcode.path<-paste0(matrix_dir,"/barcodes.tsv")
    genes.path<-paste0(matrix_dir,"/genes.tsv")
    matrix.path<-paste0(matrix_dir,"/matrix.mtx")

    zebrafish.data <- readMM(file = matrix.path) ##mac上不能读压缩文件
    gene.names = read.delim(genes.path,header = FALSE, stringsAsFactors = FALSE)
    barcode.names = read.delim(barcode.path,header = FALSE,stringsAsFactors = FALSE)
    colnames(zebrafish.data) = barcode.names$V1
    rownames(zebrafish.data) = gene.names$V1 ##把示例中的V1改成V2

    # check矩阵
    zebrafish.data[1:6, 1:6] ##check矩阵
    dim(zebrafish.data) ##check矩阵

    scRNA <- CreateSeuratObject(counts = zebrafish.data)

    saveRDS(scRNA,paste0(matrix_dir,'/counts.rds'))
}else{
    matrix_dir=paste0(matrix_dir,'/04.Matrix')
    gunzip(paste0(matrix_dir,"/barcodes.tsv.gz"))
    gunzip(paste0(matrix_dir,"/matrix.mtx.gz"))
    gunzip(paste0(matrix_dir,"/genes.tsv.gz"))

    barcode.path<-paste0(matrix_dir,"/barcodes.tsv")
    genes.path<-paste0(matrix_dir,"/genes.tsv")
    matrix.path<-paste0(matrix_dir,"/matrix.mtx")

    zebrafish.data <- readMM(file = matrix.path) ##mac上不能读压缩文件
    gene.names = read.delim(genes.path,header = FALSE, stringsAsFactors = FALSE)
    barcode.names = read.delim(barcode.path,header = FALSE,stringsAsFactors = FALSE)
    colnames(zebrafish.data) = barcode.names$V1
    rownames(zebrafish.data) = gene.names$V1 ##把示例中的V1改成V2

    # check矩阵
    zebrafish.data[1:6, 1:6] ##check矩阵
    dim(zebrafish.data) ##check矩阵

    scRNA <- CreateSeuratObject(counts = zebrafish.data)

    saveRDS(scRNA,paste0(matrix_dir,'/counts.rds'))
}}

# %%
read_file='aba'
for(i in c(1:length(all_dir))){
matrix_dir=all_dir[i]
if(file.exists(paste0(matrix_dir,"/counts.rds"))){
    read_file=c(read_file,(paste0(matrix_dir,"/counts.rds")))
}else{
    matrix_dir=paste0(matrix_dir,'/04.Matrix')
    read_file=c(read_file,(paste0(matrix_dir,"/counts.rds")))
}}
read_file=read_file[-1]
read_file
# Out:
#  [1] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6103-1-220817_web_0/04.Matrix/counts.rds"
#  [2] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6103-2-220817_web_0/04.Matrix/counts.rds"
#  [3] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6103-3-220817_web_0/04.Matrix/counts.rds"
#  [4] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6103-4-220817_web_0/04.Matrix/counts.rds"
#  [5] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6103-5-220817_web_0/04.Matrix/counts.rds"
#  [6] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6103-6-220817_web_0/04.Matrix/counts.rds"
#  [7] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6712-1-220831_web_0/04.Matrix/counts.rds"
#  [8] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6712-2-220831_web_0/04.Matrix/counts.rds"
#  [9] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6712-3-220831_web_0/04.Matrix/counts.rds"
# [10] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/6712-4-220831_web_0/04.Matrix/counts.rds"
# [11] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7220-1-221013_web_0/04.Matrix/counts.rds"
# [12] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7220-2-221013_web_0/04.Matrix/counts.rds"
# [13] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7221-1-221013_web_0/04.Matrix/counts.rds"
# [14] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7221-2-221013_web_0/04.Matrix/counts.rds"
# [15] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7222-1-221014_web_0/04.Matrix/counts.rds"
# [16] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7222-2-221014_web_0/04.Matrix/counts.rds"
# [17] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7223-1-221014_web_0/04.Matrix/counts.rds"
# [18] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7223-2-221014_web_0/04.Matrix/counts.rds"
# [19] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7224-1-221014_web_0/04.Matrix/counts.rds"
# [20] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7224-2-221014_web_0/04.Matrix/counts.rds"
# [21] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7230-1-221014_web_0/04.Matrix/counts.rds"
# [22] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7230-2-221014_web_0/04.Matrix/counts.rds"
# [23] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7231-1-221014_web_0/04.Matrix/counts.rds"
# [24] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7231-2-221014_web_0/04.Matrix/counts.rds"
# [25] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7231-3-221014_web_0/04.Matrix/counts.rds"
# [26] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7232-1-221014_web_0/04.Matrix/counts.rds"
# [27] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7232-2-221014_web_0/04.Matrix/counts.rds"
# [28] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7232-3-221014_web_0/04.Matrix/counts.rds"
# [29] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7248-1-221017_web_0/04.Matrix/counts.rds"
# [30] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/maca_clastrum/soupX.flt_Matrix/7248-2-221017_web_0/04.Matrix/counts.rds"

# %%
sceList = lapply(read_file,function(folder){ 
    readRDS(folder)
})
sceList
# Out:
# [[1]]
# An object of class Seurat
# 19241 features across 8029 samples within 1 assay
# Active assay: RNA (19241 features, 0 variable features)
#
# [[2]]
# An object of class Seurat
# 18758 features across 8216 samples within 1 assay
# Active assay: RNA (18758 features, 0 variable features)
#
# [[3]]
# An object of class Seurat
# 18338 features across 8128 samples within 1 assay
# Active assay: RNA (18338 features, 0 variable features)
#
# [[4]]
# An object of class Seurat
# 19099 features across 8236 samples within 1 assay
# Active assay: RNA (19099 features, 0 variable features)
#
# [[5]]
# An object of class Seurat
# 18285 features across 7975 samples within 1 assay
# Active assay: RNA (18285 features, 0 variable features)
#
# [[6]]
# An object of class Seurat
# 18369 features across 8627 samples within 1 assay
# Active assay: RNA (18369 features, 0 variable features)
#
# [[7]]
# An object of class Seurat
# 20017 features across 7637 samples within 1 assay
# Active assay: RNA (20017 features, 0 variable features)
#
# [[8]]
# An object of class Seurat
# 19824 features across 7805 samples within 1 assay
# Active assay: RNA (19824 features, 0 variable features)
#
# [[9]]
# An object of class Seurat
# 19696 features across 7531 samples within 1 assay
# Active assay: RNA (19696 features, 0 variable features)
#
# [[10]]
# An object of class Seurat
# 19819 features across 8000 samples within 1 assay
# Active assay: RNA (19819 features, 0 variable features)
#
# [[11]]
# An object of class Seurat
# 19818 features across 8283 samples within 1 assay
# Active assay: RNA (19818 features, 0 variable features)
#
# [[12]]
# An object of class Seurat
# 19743 features across 8015 samples within 1 assay
# Active assay: RNA (19743 features, 0 variable features)
#
# [[13]]
# An object of class Seurat
# 19750 features across 8291 samples within 1 assay
# Active assay: RNA (19750 features, 0 variable features)
#
# [[14]]
# An object of class Seurat
# 19835 features across 8338 samples within 1 assay
# Active assay: RNA (19835 features, 0 variable features)
#
# [[15]]
# An object of class Seurat
# 20053 features across 7556 samples within 1 assay
# Active assay: RNA (20053 features, 0 variable features)
#
# [[16]]
# An object of class Seurat
# 20098 features across 7602 samples within 1 assay
# Active assay: RNA (20098 features, 0 variable features)
#
# [[17]]
# An object of class Seurat
# 19958 features across 8079 samples within 1 assay
# Active assay: RNA (19958 features, 0 variable features)
#
# [[18]]
# An object of class Seurat
# 20047 features across 8014 samples within 1 assay
# Active assay: RNA (20047 features, 0 variable features)
#
# [[19]]
# An object of class Seurat
# 19670 features across 8291 samples within 1 assay
# Active assay: RNA (19670 features, 0 variable features)
#
# [[20]]
# An object of class Seurat
# 19790 features across 8247 samples within 1 assay
# Active assay: RNA (19790 features, 0 variable features)
#
# [[21]]
# An object of class Seurat
# 19247 features across 8530 samples within 1 assay
# Active assay: RNA (19247 features, 0 variable features)
#
# [[22]]
# An object of class Seurat
# 19316 features across 8539 samples within 1 assay
# Active assay: RNA (19316 features, 0 variable features)
#
# [[23]]
# An object of class Seurat
# 19151 features across 8295 samples within 1 assay
# Active assay: RNA (19151 features, 0 variable features)
#
# [[24]]
# An object of class Seurat
# 19199 features across 8090 samples within 1 assay
# Active assay: RNA (19199 features, 0 variable features)
#
# [[25]]
# An object of class Seurat
# 19238 features across 8352 samples within 1 assay
# Active assay: RNA (19238 features, 0 variable features)
#
# [[26]]
# An object of class Seurat
# 19118 features across 8574 samples within 1 assay
# Active assay: RNA (19118 features, 0 variable features)
#
# [[27]]
# An object of class Seurat
# 19169 features across 8303 samples within 1 assay
# Active assay: RNA (19169 features, 0 variable features)
#
# [[28]]
# An object of class Seurat
# 19088 features across 8548 samples within 1 assay
# Active assay: RNA (19088 features, 0 variable features)
#
# [[29]]
# An object of class Seurat
# 20023 features across 8167 samples within 1 assay
# Active assay: RNA (20023 features, 0 variable features)
#
# [[30]]
# An object of class Seurat
# 19936 features across 8225 samples within 1 assay
# Active assay: RNA (19936 features, 0 variable features)

# %%
str_extract(read_file,'[0-9][0-9][0-9][0-9]-[0-9]')
# Out:
#  [1] "6103-1" "6103-2" "6103-3" "6103-4" "6103-5" "6103-6" "6712-1" "6712-2"
#  [9] "6712-3" "6712-4" "7220-1" "7220-2" "7221-1" "7221-2" "7222-1" "7222-2"
# [17] "7223-1" "7223-2" "7224-1" "7224-2" "7230-1" "7230-2" "7231-1" "7231-2"
# [25] "7231-3" "7232-1" "7232-2" "7232-3" "7248-1" "7248-2"

# %%
length(all_dir)
# Out:
# [1] 30

# %%
read_file_renew=str_extract(read_file,'[0-9][0-9][0-9][0-9]-[0-9]')

read_file_renew

sce.big <- merge(sceList[[1]], 
                 y = c(sceList[[2]],sceList[[3]],sceList[[4]],
                       sceList[[5]],sceList[[6]],
                       sceList[[7]],sceList[[8]],sceList[[9]],sceList[[10]],sceList[[11]],
                       sceList[[12]],sceList[[13]],
                       sceList[[14]], sceList[[15]],sceList[[16]],
                       sceList[[17]],sceList[[18]],sceList[[19]],sceList[[20]],sceList[[21]],
                       sceList[[22]],sceList[[23]],
                       sceList[[24]], sceList[[25]],sceList[[26]],
                       sceList[[27]],sceList[[28]],sceList[[29]],sceList[[30]]), 
                 add.cell.ids = read_file_renew,
                 project = "macaca")

table(sce.big$orig.ident)

sce.big@meta.data$group=str_extract(rownames(sce.big@meta.data),'[0-9][0-9][0-9][0-9]-[0-9]')
# Out:
#  [1] "6103-1" "6103-2" "6103-3" "6103-4" "6103-5" "6103-6" "6712-1" "6712-2"
#  [9] "6712-3" "6712-4" "7220-1" "7220-2" "7221-1" "7221-2" "7222-1" "7222-2"
# [17] "7223-1" "7223-2" "7224-1" "7224-2" "7230-1" "7230-2" "7231-1" "7231-2"
# [25] "7231-3" "7232-1" "7232-2" "7232-3" "7248-1" "7248-2"
# SeuratProject
#        244523

# %%
saveRDS(sce.big,'/home/liuyx/liuyuxuan/spa_seurat/cla/renew_data0425/sn_rna_data/snrna_matrix_20230420/sum_data/maca/macaca_snrna_all_soupX_unfil_0425.rds')
