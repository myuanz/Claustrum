# %%
library(dplyr)
library(Seurat)
library(patchwork)
library(stringr)
library(Matrix)
library(R.utils)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# The legacy packages maptools, rgdal, and rgeos, underpinning this package
# will retire shortly. Please refer to R-spatial evolution reports on
# https://r-spatial.org/r/2023/05/15/evolution4.html for details.
# This package is now running under evolution status 0
#
# rgeos version: 0.6-3, (SVN revision 696)
#  GEOS runtime version: 3.11.0-CAPI-1.17.0
#  Please note that rgeos will be retired during October 2023,
# plan transition to sf or terra functions using GEOS at your earliest convenience.
# See https://r-spatial.org/r/2023/05/15/evolution4.html for details.
#  GEOS using OverlayNG
#  Linking to sp version: 1.6-0
#  Polygon checking: TRUE
#
#
# Attaching SeuratObject
#
# Attaching sp
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.25.0 (2022-06-12 02:20:02 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.12.2 (2022-11-11 22:00:03 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, warnings

# %%
all_dir=list.dirs('/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_1/soupX.flt_Matrix')
all_dir=all_dir[grep('1$',all_dir)]
length(all_dir)
all_dir1=all_dir
all_dir1
# Out:
# [1] 4
# [1] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_1/soupX.flt_Matrix/6708-1-220831_web_1"
# [2] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_1/soupX.flt_Matrix/6708-2-220831_web_1"
# [3] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_1/soupX.flt_Matrix/6708-3-220831_web_1"
# [4] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_1/soupX.flt_Matrix/6708-4-220831_web_1"

# %%
all_dir=list.dirs('/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix')
all_dir=all_dir[grep('1$',all_dir)]
length(all_dir)
all_dir2=all_dir
all_dir2
# Out:
# [1] 22
#  [1] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-1-230329_web_1"
#  [2] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-10-230329_web_1"
#  [3] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-2-230329_web_1"
#  [4] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-3-230329_web_1"
#  [5] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-4-230329_web_1"
#  [6] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-5-230329_web_1"
#  [7] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-6-230329_web_1"
#  [8] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-7-230329_web_1"
#  [9] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-8-230329_web_1"
# [10] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-9-230329_web_1"
# [11] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-1-230329_web_1"
# [12] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-2-230329_web_1"
# [13] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-3-230329_web_1"
# [14] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-4-230329_web_1"
# [15] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-5-230329_web_1"
# [16] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-6-230329_web_1"
# [17] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-7-230329_web_1"
# [18] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-8-230329_web_1"
# [19] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2194-10-230329_web_1"
# [20] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2194-11-230329_web_1"
# [21] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2194-12-230329_web_1"
# [22] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2194-9-230329_web_1"

# %%
all_dir=c(all_dir1,all_dir2)
all_dir
length(all_dir)
# Out:
#  [1] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_1/soupX.flt_Matrix/6708-1-220831_web_1"
#  [2] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_1/soupX.flt_Matrix/6708-2-220831_web_1"
#  [3] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_1/soupX.flt_Matrix/6708-3-220831_web_1"
#  [4] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_1/soupX.flt_Matrix/6708-4-220831_web_1"
#  [5] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-1-230329_web_1"
#  [6] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-10-230329_web_1"
#  [7] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-2-230329_web_1"
#  [8] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-3-230329_web_1"
#  [9] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-4-230329_web_1"
# [10] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-5-230329_web_1"
# [11] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-6-230329_web_1"
# [12] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-7-230329_web_1"
# [13] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-8-230329_web_1"
# [14] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-9-230329_web_1"
# [15] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-1-230329_web_1"
# [16] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-2-230329_web_1"
# [17] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-3-230329_web_1"
# [18] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-4-230329_web_1"
# [19] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-5-230329_web_1"
# [20] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-6-230329_web_1"
# [21] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-7-230329_web_1"
# [22] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-8-230329_web_1"
# [23] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2194-10-230329_web_1"
# [24] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2194-11-230329_web_1"
# [25] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2194-12-230329_web_1"
# [26] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2194-9-230329_web_1"
# [1] 26

# %%
for(i in c(5:length(all_dir))){matrix_dir=all_dir[i]

if(file.exists(paste0(matrix_dir,"/barcodes.tsv.gz"))){
    gunzip(paste0(matrix_dir,"/barcodes.tsv.gz"))
    gunzip(paste0(matrix_dir,"/matrix.mtx.gz"))
    if(file.exists(paste0(matrix_dir,"/genes.tsv.gz"))){
        gunzip(paste0(matrix_dir,"/genes.tsv.gz"))}else{
        gunzip(paste0(matrix_dir,"/features.tsv.gz"))
    }
    barcode.path<-paste0(matrix_dir,"/barcodes.tsv")
    if(file.exists(paste0(matrix_dir,"/genes.tsv"))){
        genes.path<-(paste0(matrix_dir,"/genes.tsv"))}else{
        genes.path<-(paste0(matrix_dir,"/features.tsv"))
    }
    matrix.path<-paste0(matrix_dir,"/matrix.mtx")

    zebrafish.data <- readMM(file = matrix.path) ##mac上不能读压缩文件
    gene.names = read.delim(genes.path,header = FALSE, stringsAsFactors = FALSE)
    barcode.names = read.delim(barcode.path,header = FALSE,stringsAsFactors = FALSE)
    colnames(zebrafish.data) = barcode.names$V1
    rownames(zebrafish.data) = gene.names$V1 ##把示例中的V1改成V2

    # check矩阵
    zebrafish.data[1:6, 1:6] ##check矩阵
    dim(zebrafish.data) ##check矩阵

    scRNA <- CreateSeuratObject(counts = zebrafish.data)

    saveRDS(scRNA,paste0(matrix_dir,'/counts.rds'))
}else{
    matrix_dir=paste0(matrix_dir,'/04.Matrix')
    gunzip(paste0(matrix_dir,"/barcodes.tsv.gz"))
    gunzip(paste0(matrix_dir,"/matrix.mtx.gz"))
    if(file.exists(paste0(matrix_dir,"/genes.tsv.gz"))){
        gunzip(paste0(matrix_dir,"/genes.tsv.gz"))}else{
        gunzip(paste0(matrix_dir,"/features.tsv.gz"))
    }

    barcode.path<-paste0(matrix_dir,"/barcodes.tsv")
    if(file.exists(paste0(matrix_dir,"/genes.tsv"))){
        genes.path<-(paste0(matrix_dir,"/genes.tsv"))}else{
        genes.path<-(paste0(matrix_dir,"/features.tsv"))
    }
    matrix.path<-paste0(matrix_dir,"/matrix.mtx")

    zebrafish.data <- readMM(file = matrix.path) ##mac上不能读压缩文件
    gene.names = read.delim(genes.path,header = FALSE, stringsAsFactors = FALSE)
    barcode.names = read.delim(barcode.path,header = FALSE,stringsAsFactors = FALSE)
    colnames(zebrafish.data) = barcode.names$V1
    rownames(zebrafish.data) = gene.names$V1 ##把示例中的V1改成V2

    # check矩阵
    zebrafish.data[1:6, 1:6] ##check矩阵
    dim(zebrafish.data) ##check矩阵

    scRNA <- CreateSeuratObject(counts = zebrafish.data)

    saveRDS(scRNA,paste0(matrix_dir,'/counts.rds'))
}}

# %%
read_file='aba'
for(i in c(1:length(all_dir))){
matrix_dir=all_dir[i]
if(file.exists(paste0(matrix_dir,"/counts.rds"))){
    read_file=c(read_file,(paste0(matrix_dir,"/counts.rds")))
}else{
    matrix_dir=paste0(matrix_dir,'/04.Matrix')
    read_file=c(read_file,(paste0(matrix_dir,"/counts.rds")))
}}
read_file=read_file[-1]
read_file
# Out:
#  [1] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_1/soupX.flt_Matrix/6708-1-220831_web_1/04.Matrix/counts.rds"
#  [2] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_1/soupX.flt_Matrix/6708-2-220831_web_1/04.Matrix/counts.rds"
#  [3] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_1/soupX.flt_Matrix/6708-3-220831_web_1/04.Matrix/counts.rds"
#  [4] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_1/soupX.flt_Matrix/6708-4-220831_web_1/04.Matrix/counts.rds"
#  [5] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-1-230329_web_1/04.Matrix/counts.rds"
#  [6] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-10-230329_web_1/04.Matrix/counts.rds"
#  [7] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-2-230329_web_1/04.Matrix/counts.rds"
#  [8] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-3-230329_web_1/04.Matrix/counts.rds"
#  [9] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-4-230329_web_1/04.Matrix/counts.rds"
# [10] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-5-230329_web_1/04.Matrix/counts.rds"
# [11] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-6-230329_web_1/04.Matrix/counts.rds"
# [12] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-7-230329_web_1/04.Matrix/counts.rds"
# [13] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-8-230329_web_1/04.Matrix/counts.rds"
# [14] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2192-9-230329_web_1/04.Matrix/counts.rds"
# [15] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-1-230329_web_1/04.Matrix/counts.rds"
# [16] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-2-230329_web_1/04.Matrix/counts.rds"
# [17] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-3-230329_web_1/04.Matrix/counts.rds"
# [18] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-4-230329_web_1/04.Matrix/counts.rds"
# [19] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-5-230329_web_1/04.Matrix/counts.rds"
# [20] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-6-230329_web_1/04.Matrix/counts.rds"
# [21] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-7-230329_web_1/04.Matrix/counts.rds"
# [22] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2193-8-230329_web_1/04.Matrix/counts.rds"
# [23] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2194-10-230329_web_1/04.Matrix/counts.rds"
# [24] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2194-11-230329_web_1/04.Matrix/counts.rds"
# [25] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2194-12-230329_web_1/04.Matrix/counts.rds"
# [26] "/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/Batch_2/soupX.flt_Matrix/2194-9-230329_web_1/04.Matrix/counts.rds"

# %%
sceList = lapply(read_file,function(folder){ 
    readRDS(folder)
})
sceList
# Out:
# [[1]]
# An object of class Seurat
# 28282 features across 8022 samples within 1 assay
# Active assay: RNA (28282 features, 0 variable features)
#
# [[2]]
# An object of class Seurat
# 29426 features across 8303 samples within 1 assay
# Active assay: RNA (29426 features, 0 variable features)
#
# [[3]]
# An object of class Seurat
# 28636 features across 7798 samples within 1 assay
# Active assay: RNA (28636 features, 0 variable features)
#
# [[4]]
# An object of class Seurat
# 29065 features across 8315 samples within 1 assay
# Active assay: RNA (29065 features, 0 variable features)
#
# [[5]]
# An object of class Seurat
# 28994 features across 6938 samples within 1 assay
# Active assay: RNA (28994 features, 0 variable features)
#
# [[6]]
# An object of class Seurat
# 28931 features across 6798 samples within 1 assay
# Active assay: RNA (28931 features, 0 variable features)
#
# [[7]]
# An object of class Seurat
# 28487 features across 6737 samples within 1 assay
# Active assay: RNA (28487 features, 0 variable features)
#
# [[8]]
# An object of class Seurat
# 29016 features across 6955 samples within 1 assay
# Active assay: RNA (29016 features, 0 variable features)
#
# [[9]]
# An object of class Seurat
# 28665 features across 6667 samples within 1 assay
# Active assay: RNA (28665 features, 0 variable features)
#
# [[10]]
# An object of class Seurat
# 28945 features across 7093 samples within 1 assay
# Active assay: RNA (28945 features, 0 variable features)
#
# [[11]]
# An object of class Seurat
# 28211 features across 5807 samples within 1 assay
# Active assay: RNA (28211 features, 0 variable features)
#
# [[12]]
# An object of class Seurat
# 29091 features across 6829 samples within 1 assay
# Active assay: RNA (29091 features, 0 variable features)
#
# [[13]]
# An object of class Seurat
# 28921 features across 7094 samples within 1 assay
# Active assay: RNA (28921 features, 0 variable features)
#
# [[14]]
# An object of class Seurat
# 29100 features across 6940 samples within 1 assay
# Active assay: RNA (29100 features, 0 variable features)
#
# [[15]]
# An object of class Seurat
# 28648 features across 7043 samples within 1 assay
# Active assay: RNA (28648 features, 0 variable features)
#
# [[16]]
# An object of class Seurat
# 27896 features across 7287 samples within 1 assay
# Active assay: RNA (27896 features, 0 variable features)
#
# [[17]]
# An object of class Seurat
# 28216 features across 7286 samples within 1 assay
# Active assay: RNA (28216 features, 0 variable features)
#
# [[18]]
# An object of class Seurat
# 27896 features across 7265 samples within 1 assay
# Active assay: RNA (27896 features, 0 variable features)
#
# [[19]]
# An object of class Seurat
# 28344 features across 7456 samples within 1 assay
# Active assay: RNA (28344 features, 0 variable features)
#
# [[20]]
# An object of class Seurat
# 28944 features across 7318 samples within 1 assay
# Active assay: RNA (28944 features, 0 variable features)
#
# [[21]]
# An object of class Seurat
# 28241 features across 7542 samples within 1 assay
# Active assay: RNA (28241 features, 0 variable features)
#
# [[22]]
# An object of class Seurat
# 28234 features across 7868 samples within 1 assay
# Active assay: RNA (28234 features, 0 variable features)
#
# [[23]]
# An object of class Seurat
# 28225 features across 6604 samples within 1 assay
# Active assay: RNA (28225 features, 0 variable features)
#
# [[24]]
# An object of class Seurat
# 28093 features across 6263 samples within 1 assay
# Active assay: RNA (28093 features, 0 variable features)
#
# [[25]]
# An object of class Seurat
# 28074 features across 6777 samples within 1 assay
# Active assay: RNA (28074 features, 0 variable features)
#
# [[26]]
# An object of class Seurat
# 28536 features across 6468 samples within 1 assay
# Active assay: RNA (28536 features, 0 variable features)

# %%
read_file_renew=str_extract(read_file,'[0-9][0-9][0-9][0-9]-[0-9]*')

read_file_renew

sce.big <- merge(sceList[[1]], 
                 y = c(sceList[[2]],sceList[[3]],sceList[[4]],
                       sceList[[5]],sceList[[6]],
                       sceList[[7]],sceList[[8]],sceList[[9]],sceList[[10]],sceList[[11]],
                       sceList[[12]],sceList[[13]],
                       sceList[[14]], sceList[[15]],sceList[[16]],
                       sceList[[17]],sceList[[18]],sceList[[19]],sceList[[20]],sceList[[21]],
                       sceList[[22]],sceList[[23]],
                       sceList[[24]], sceList[[25]],sceList[[26]]), 
                 add.cell.ids = read_file_renew,
                 project = "macaca")

table(sce.big$orig.ident)

sce.big@meta.data$group=str_extract(rownames(sce.big@meta.data),'[0-9][0-9][0-9][0-9]-[0-9]')
# Out:
#  [1] "6708-1"  "6708-2"  "6708-3"  "6708-4"  "2192-1"  "2192-10" "2192-2"
#  [8] "2192-3"  "2192-4"  "2192-5"  "2192-6"  "2192-7"  "2192-8"  "2192-9"
# [15] "2193-1"  "2193-2"  "2193-3"  "2193-4"  "2193-5"  "2193-6"  "2193-7"
# [22] "2193-8"  "2194-10" "2194-11" "2194-12" "2194-9"
# SeuratProject
#        185473

# %%
saveRDS(sce.big,'/home/liuyx/liuyuxuan/spa_seurat/cla/renew_sndata_0619_mouse_mamoset/20230619.cla_snrna/mamoset/mamoset_snrna_all_soupX_unfil_0619.rds')
